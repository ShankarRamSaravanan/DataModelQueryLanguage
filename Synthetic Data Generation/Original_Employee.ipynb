# %%
from urllib import request, error
from urllib.parse import urlencode
import json
import time
import re 
API_VERSION = '1.3'
import pandas as pd
import numpy as np
import time
URL = 'https://randomuser.me/api/?nat=us'.format(API_VERSION)   
JSON_FILE = json.loads(request.urlopen(URL).read())
Title =JSON_FILE['results'][0]
Title
# Out:
# {'gender': 'female',
#  'name': {'title': 'Mrs', 'first': 'Jeanette', 'last': 'Nichols'},
#  'location': {'street': {'number': 3656, 'name': 'College St'},
#   'city': 'Grants Pass',
#   'state': 'Maryland',
#   'country': 'United States',
#   'postcode': 50815,
#   'coordinates': {'latitude': '-26.8276', 'longitude': '164.6487'},
#   'timezone': {'offset': '-10:00', 'description': 'Hawaii'}},
#  'email': 'jeanette.nichols@example.com',
#  'login': {'uuid': '7a915156-7c69-4343-98a1-411b4ee56cbd',
#   'username': 'beautifulelephant207',
#   'password': 'native',
#   'salt': 'XyKmrneI',
#   'md5': 'b011f495223f66b9111978c05008d52f',
#   'sha1': '6d09df80efd3685b03ff3f3f7a32af626a7825e4',
#   'sha256': '07fc62874a9af7a9d5af82ab4bdb4f59561d6613a4aec3e0c88afc5e1bd215b0'},
#  'dob': {'date': '1950-07-07T04:07:56.951Z', 'age': 72},
#  'registered': {'date': '2016-04-16T01:33:08.801Z', 'age': 6},
#  'phone': '(993) 577-8975',
#  'cell': '(234) 976-4107',
# ...

# %%
Customer = pd.read_csv("C:/ram/FALL/DMQL/Project/Customer.csv")

# %%
Customer
# Out:
#            ID            Name                     Email          SSN  \
# 0     6614212     Laurie Peck     laurie.peck@gmail.com  791-26-2139
# 1     6716543       Joel Webb       joel.webb@gmail.com  183-58-8490
# 2     8601028  Jordan Simpson  jordan.simpson@gmail.com  632-34-9201
# 3     7446086  Jeffrey Barnes  jeffrey.barnes@gmail.com  830-21-4869
# 4     4122549      Allan Bell      allan.bell@gmail.com  260-77-2373
# ...       ...             ...                       ...          ...
# 9995  8532903      Megan Sims      megan.sims@gmail.com  479-49-9146
# 9996  5078380      Mia Howard      mia.howard@gmail.com  348-92-7003
# 9997  8554324       Pedro Day       pedro.day@gmail.com  134-07-3044
# 9998  9673332    Alex Nichols    alex.nichols@gmail.com  041-85-4096
# 9999  5590098   Zoey Caldwell   zoey.caldwell@gmail.com  702-80-2787
#
#                  Phone                                            Address
# ...

# %%
#Empid

Employee_id = np.random.randint(18972524,99999999,size=(250))
Employee_Id = Employee_id.tolist()



upd_Employee_Id=[]
for i in Employee_Id:
    upd_Employee_Id.append("BSA"+str(i))
upd_Employee_Id
# Out:
# ['BSA76886793',
#  'BSA59860024',
#  'BSA46800944',
#  'BSA53277210',
#  'BSA77775339',
#  'BSA77601566',
#  'BSA84334972',
#  'BSA76919998',
#  'BSA93892722',
#  'BSA66794539',
#  'BSA20297786',
#  'BSA89263802',
#  'BSA99905939',
#  'BSA84687964',
#  'BSA28549658',
#  'BSA86580904',
#  'BSA63868663',
#  'BSA48577121',
#  'BSA71937646',
#  'BSA68889538',
#  'BSA53626331',
#  'BSA72456314',
#  'BSA70891451',
#  'BSA29949826',
#  'BSA70065662',
#  'BSA39556327',
#  'BSA50792198',
#  'BSA61822569',
#  'BSA86346296',
#  'BSA63271525',
#  'BSA50490728',
#  'BSA95864796',
#  'BSA52681156',
#  'BSA74593066',
#  'BSA42037307',
#  'BSA79618525',
#  'BSA93003953',
#  'BSA19711084',
#  'BSA23846206',
#  'BSA71505966',
#  'BSA55770214',
#  'BSA63515550',
#  'BSA99693589',
#  'BSA44950717',
#  'BSA77492051',
#  'BSA62964808',
#  'BSA43378335',
#  'BSA20107992',
#  'BSA95299465',
#  'BSA39359909',
#  'BSA37586962',
#  'BSA56764922',
#  'BSA57020437',
#  'BSA82692530',
#  'BSA58057811',
# ...

# %%
Customer.iloc[[  13, 8020, 2195, 9625, 4476, 5172, 8175, 1995, 9796,   34, 2634,
       9905,  590, 3394, 8044, 1889, 7248, 1076, 1578, 1393, 1916, 4750,
       5121, 8327,  173, 9192, 5054, 2570, 4383, 5791, 5773, 3357, 4502,
       4922, 3841, 1206, 2588,  141, 2265, 7711, 1996, 5094, 4183, 9559,
       4846, 6092, 2241,  363, 8992, 8987, 1780, 2119, 7999, 1107, 4981,
       8469, 3604, 6191, 6036, 4309, 1442, 4893, 1917, 4150, 1949, 8896,
       8433, 2796, 3133, 4591, 1146, 2191, 7261,  416, 6410, 8787, 4270,
       1346,  923, 7273, 6076, 9947,  340, 6706, 4709,  189, 6797, 1312,
        700, 4690, 2325,  961, 3673, 5272, 3223, 2495, 7058, 6885, 9277,
       8188, 5631, 6207,  884, 8994, 8134, 5502, 2363, 1029, 8027, 5348,
       7178, 6802, 7182, 1802, 8502, 8579,  853, 1082,  726, 5074, 8670,
        400,  236, 1815, 6193, 2358, 3351, 5748, 4417, 8285, 3289, 4130,
        649, 8857, 1945, 8030,  926, 8699, 4536, 1093, 4711, 2100, 5113,
       9257, 8033, 3245,  656, 7549, 2174, 3624, 1665, 2843, 4999, 5405,
       2400, 6380, 1701, 5377, 2429, 8962,  610, 5983, 4715, 8504, 6814,
       8326, 8037, 5952, 9029, 3484, 7413, 5441, 3793, 9558, 5164, 2128,
        678, 4921, 5228, 6690,  260, 3887, 2568, 1131, 9493,  270,  184,
       4650, 3110, 3483, 1842,    6, 9434,   38, 6334, 6817, 1035,   79,
       9903, 5570, 5284,  874, 5973, 6380, 4569, 8402, 3658, 1836, 5187,
       8910, 7223, 4765, 6472, 7644, 8432, 7629, 9261, 5518, 3460, 5806,
       7786, 1169, 6356, 9148,  795, 1378, 2965, 9851, 3316, 5366, 6328,
        750, 8833, 2147, 5422, 3184, 9578, 1739, 6716, 9680, 5760, 4774,
       9267, 7815, 9044, 3951, 4036, 6835, 3407, 8473], [1,2,4]]
# Out:
#                    Name                        Email             Phone
# 13       Courtney Ellis     courtney.ellis@gmail.com  +1(611) 533-1582
# 8020       June Coleman       june.coleman@gmail.com  +1(929) 232-0821
# 2195       Jeffrey Pena       jeffrey.pena@gmail.com  +1(316) 743-2420
# 9625    Nelson Caldwell    nelson.caldwell@gmail.com  +1(868) 855-1330
# 4476       Logan Nelson       logan.nelson@gmail.com  +1(446) 999-6298
# ...                 ...                          ...               ...
# 3951  Priscilla Wheeler  priscilla.wheeler@gmail.com  +1(217) 987-0545
# 4036          Joel Carr          joel.carr@gmail.com  +1(646) 787-2321
# 6835       Edwin Curtis       edwin.curtis@gmail.com  +1(878) 916-3689
# 3407      Melinda Jones      melinda.jones@gmail.com  +1(285) 774-4189
# 8473  Marjorie Morrison  marjorie.morrison@gmail.com  +1(976) 362-5417
#
# [250 rows x 3 columns]

# %%
a=np.random.randint(25, size=250)
# A=a.tolist()/

b=['BOFABUF01','BOFABUF02','BOFABUF03','BOFABUF04','BOFABUF05','BOFABUF06','BOFABUF07','BOFABUF08','BOFABUF09','BOFABUF10','BOFABUF11','BOFABUF12','BOFABUF13','BOFABUF14','BOFABUF15','BOFABUF16','BOFABUF17','BOFABUF18','BOFABUF19','BOFABUF20','BOFABUF21','BOFABUF22','BOFABUF23','BOFABUF24','BOFABUF25']
Branch_name =["Fountain Plaza", "Elmwood"," Military Road","South Park"," Fillmore","  Bailey Delavan", "North Park"," Williamsville"," West Seneca" ," Getzville"," Orchard Park"," Kenmore"," East Aurora"," Tonawanada"," Hamburg", "North Tonawanda","Depe","Lancaster","Brierwood","Englewood Avenue","Geico","Boulevard","Evans","Larkin","Black Rock"]

print(len(Branch_name))


Branch_Id=[]
for i in a:
   Branch_Id.append(b[i])   
#print(Branch_Id)
#dct = defaultdict(str)

#for j in Branch_Id:
#    if j not in dct:
#        dct[j]=0
#    else:
#        dct[j]+=1
#dct = dict(sorted(dct.items()))
#dct



#for i,j in zip(Branch_Id,Branch_name):
#    print(i,j)
      
branch_dict = {}
for k,v in zip(b,Branch_name):
    #print(k)
    branch_dict.update({k: v })
    #print(h)
    
print(branch_dict)

#for i,j in zip(branch_dict.keys(),branch_dict.values()):
#    print(i,j)
Branch_name_Df=[]
for i in Branch_Id:
    Branch_name_Df.append(branch_dict[i])
    
    
    
Branch_name_Df
# Out:
# 25
# {'BOFABUF01': 'Fountain Plaza', 'BOFABUF02': 'Elmwood', 'BOFABUF03': ' Military Road', 'BOFABUF04': 'South Park', 'BOFABUF05': ' Fillmore', 'BOFABUF06': '  Bailey Delavan', 'BOFABUF07': 'North Park', 'BOFABUF08': ' Williamsville', 'BOFABUF09': ' West Seneca', 'BOFABUF10': ' Getzville', 'BOFABUF11': ' Orchard Park', 'BOFABUF12': ' Kenmore', 'BOFABUF13': ' East Aurora', 'BOFABUF14': ' Tonawanada', 'BOFABUF15': ' Hamburg', 'BOFABUF16': 'North Tonawanda', 'BOFABUF17': 'Depe', 'BOFABUF18': 'Lancaster', 'BOFABUF19': 'Brierwood', 'BOFABUF20': 'Englewood Avenue', 'BOFABUF21': 'Geico', 'BOFABUF22': 'Boulevard', 'BOFABUF23': 'Evans', 'BOFABUF24': 'Larkin', 'BOFABUF25': 'Black Rock'}
# [' Orchard Park',
#  ' Williamsville',
#  'Fountain Plaza',
#  'Larkin',
#  'Geico',
#  'North Park',
#  'Depe',
#  'South Park',
#  ' West Seneca',
#  'Evans',
#  ' Fillmore',
#  'South Park',
#  'Evans',
#  ' Kenmore',
#  ' Orchard Park',
#  'North Tonawanda',
#  ' West Seneca',
#  ' Hamburg',
# ...

# %%
Branch_Id
# Out:
# ['BOFABUF17',
#  'BOFABUF09',
#  'BOFABUF01',
#  'BOFABUF19',
#  'BOFABUF12',
#  'BOFABUF04',
#  'BOFABUF12',
#  'BOFABUF16',
#  'BOFABUF14',
#  'BOFABUF20',
#  'BOFABUF23',
#  'BOFABUF04',
#  'BOFABUF24',
#  'BOFABUF16',
#  'BOFABUF07',
#  'BOFABUF23',
#  'BOFABUF08',
#  'BOFABUF21',
#  'BOFABUF07',
#  'BOFABUF15',
#  'BOFABUF18',
#  'BOFABUF07',
#  'BOFABUF08',
#  'BOFABUF24',
#  'BOFABUF11',
#  'BOFABUF02',
#  'BOFABUF22',
#  'BOFABUF01',
#  'BOFABUF16',
#  'BOFABUF22',
#  'BOFABUF15',
#  'BOFABUF05',
#  'BOFABUF14',
#  'BOFABUF09',
#  'BOFABUF07',
#  'BOFABUF14',
#  'BOFABUF18',
#  'BOFABUF11',
#  'BOFABUF14',
#  'BOFABUF11',
#  'BOFABUF02',
#  'BOFABUF11',
#  'BOFABUF11',
#  'BOFABUF15',
#  'BOFABUF23',
#  'BOFABUF06',
#  'BOFABUF16',
#  'BOFABUF11',
#  'BOFABUF01',
#  'BOFABUF05',
#  'BOFABUF25',
#  'BOFABUF20',
#  'BOFABUF07',
#  'BOFABUF12',
#  'BOFABUF03',
#  'BOFABUF21',
#  'BOFABUF13',
#  'BOFABUF05',
#  'BOFABUF07',
#  'BOFABUF09',
#  'BOFABUF15',
#  'BOFABUF10',
# ...

# %%
Employee = pd.DataFrame(upd_Employee_Id, columns=['Employee_Id'])

Employee['Emp_Name'] = Customer['Name']
Employee['Email_Id'] = Customer['Email']
Employee['Phone'] = Customer['Phone']
Employee['Branch_name'] = Branch_name_Df
Employee['Branch_id'] = Branch_Id

# %%
Employee
# Out:
#      Employee_Id           Emp_Name                     Email_Id  \
# 0    BSA76886793        Laurie Peck        laurie.peck@gmail.com
# 1    BSA59860024          Joel Webb          joel.webb@gmail.com
# 2    BSA46800944     Jordan Simpson     jordan.simpson@gmail.com
# 3    BSA53277210     Jeffrey Barnes     jeffrey.barnes@gmail.com
# 4    BSA77775339         Allan Bell         allan.bell@gmail.com
# ..           ...                ...                          ...
# 245  BSA27703440  Charlotte Pearson  charlotte.pearson@gmail.com
# 246  BSA76225705        Tina Willis        tina.willis@gmail.com
# 247  BSA45678507      Daisy Garrett      daisy.garrett@gmail.com
# 248  BSA39994906       Cathy Fisher       cathy.fisher@gmail.com
# 249  BSA90728467      Darryl Wagner      darryl.wagner@gmail.com
#
#                 Phone     Branch_name  Branch_id
# 0    +1(357) 798-4657            Depe  BOFABUF17
# 1    +1(985) 895-5467     West Seneca  BOFABUF09
# ...

# %%
h=Employee['Email_Id'].tolist()



upd_Emp_email =[]
for i in h:
    upd_Emp_email.append(i.replace("@gmail.com","@bsabank.com"))
    
upd_Emp_email
# Out:
# ['laurie.peck@bsabank.com',
#  'joel.webb@bsabank.com',
#  'jordan.simpson@bsabank.com',
#  'jeffrey.barnes@bsabank.com',
#  'allan.bell@bsabank.com',
#  'terry.simmmons@bsabank.com',
#  'misty.herrera@bsabank.com',
#  'shane.richards@bsabank.com',
#  'eleanor.banks@bsabank.com',
#  'gregory.tucker@bsabank.com',
#  'stanley.hart@bsabank.com',
#  'gary.watson@bsabank.com',
#  'enrique.henderson@bsabank.com',
#  'courtney.ellis@bsabank.com',
#  'terry.wallace@bsabank.com',
#  'dawn.baker@bsabank.com',
#  'alexander.burton@bsabank.com',
#  'carole.alexander@bsabank.com',
#  'larry.herrera@bsabank.com',
#  'misty.mendoza@bsabank.com',
#  'colleen.davidson@bsabank.com',
#  'hazel.chavez@bsabank.com',
#  'edgar.simmmons@bsabank.com',
#  'joan.hawkins@bsabank.com',
#  'dave.wade@bsabank.com',
#  'violet.simpson@bsabank.com',
#  'tracy.rice@bsabank.com',
#  'eli.wells@bsabank.com',
#  'ann.holt@bsabank.com',
#  'nevaeh.howard@bsabank.com',
#  'jerry.turner@bsabank.com',
# ...

# %%
Employee['Email_Id'] = upd_Emp_email

# %%
Employee
# Out:
#      Employee_Id           Emp_Name                       Email_Id  \
# 0    BSA76886793        Laurie Peck        laurie.peck@bsabank.com
# 1    BSA59860024          Joel Webb          joel.webb@bsabank.com
# 2    BSA46800944     Jordan Simpson     jordan.simpson@bsabank.com
# 3    BSA53277210     Jeffrey Barnes     jeffrey.barnes@bsabank.com
# 4    BSA77775339         Allan Bell         allan.bell@bsabank.com
# ..           ...                ...                            ...
# 245  BSA27703440  Charlotte Pearson  charlotte.pearson@bsabank.com
# 246  BSA76225705        Tina Willis        tina.willis@bsabank.com
# 247  BSA45678507      Daisy Garrett      daisy.garrett@bsabank.com
# 248  BSA39994906       Cathy Fisher       cathy.fisher@bsabank.com
# 249  BSA90728467      Darryl Wagner      darryl.wagner@bsabank.com
#
#                 Phone     Branch_name  Branch_id
# 0    +1(357) 798-4657            Depe  BOFABUF17
# 1    +1(985) 895-5467     West Seneca  BOFABUF09
# ...

# %%
Employee.to_csv('Employee.csv')
