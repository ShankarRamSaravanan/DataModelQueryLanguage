# %%
from urllib import request, error
from urllib.parse import urlencode
import numpy as np
import json
import time
import re 
API_VERSION = '1.3'
import pandas as pd
import time
URL = 'https://randomuser.me/api/?nat=us'.format(API_VERSION)   
JSON_FILE = json.loads(request.urlopen(URL).read())
Title =JSON_FILE['results'][0]['login']
Title
# Out:
# {'uuid': 'b4cafb9e-4ae5-401f-9de2-d28fc94d332b',
#  'username': 'blacksnake263',
#  'password': 'tammy',
#  'salt': 'P3vbf921',
#  'md5': '19c9fc1e487cad3945bc5da851edb1bb',
#  'sha1': '95f288e77b5fd9a1a9dc6a53c0ea5a1870896652',
#  'sha256': '3fc92a946bbff10db76855abc47d13339ff1f2d1100a7c476fc4b933fa2ebe7c'}

# %%
password =[]
for i in range(10000):
    URL = 'https://randomuser.me/api/?nat=us'.format(API_VERSION)   
    JSON_FILE = json.loads(request.urlopen(URL).read())
    Title =JSON_FILE['results'][0]['login']['password']
    password.append(Title)
    
password
# Out:
# ['jethro',
#  'tanner',
#  'downtown',
#  'doudou',
#  'lockerroom',
#  'shalom',
#  'jonas',
#  'great',
#  'cold',
#  'darkness',
#  'wizard',
#  'romero',
#  'cottage',
#  '1965',
#  'cobain',
#  'memphis',
#  'loveme',
#  'sinbad',
#  'yousuck',
#  'pokey',
#  '1022',
#  'dean',
#  'stevens',
#  'coochie',
#  'roscoe',
#  'beast',
#  'apples',
#  'maxime',
#  'danny1',
#  'yong',
#  'steele',
#  'calgary',
#  'rusty1',
#  'spurs',
#  'coming',
#  'clowns',
#  'facial',
#  'qwertz',
#  'corn',
#  'service',
#  'dakota',
#  'skyler',
#  'fruity',
#  'willis',
#  'theresa',
#  'shakur',
#  'emmett',
#  'backup',
#  'sabine',
#  'manfred',
#  'tickling',
#  'blunt',
#  'silver',
#  'wild',
#  'yamahar1',
#  'tito',
#  'drifter',
#  'mexico',
#  'island',
#  'cloud',
#  'evolutio',
#  'life',
#  '1234567',
#  'katie',
#  'kahlua',
#  'trucking',
#  'isabel',
#  'peter',
#  'hannah',
#  'twilight',
#  'tracker',
#  'irish',
#  'sweety',
#  'doubled',
#  'chicken1',
#  'time',
#  'transit',
#  'beavis1',
#  'carnage',
#  '112358',
#  'dude',
#  'buffalo',
#  'challeng',
#  'europa',
#  'aptiva',
#  'pauline',
#  'phoebe',
#  'comet',
#  'catwoman',
#  'mother',
#  'corwin',
#  'cynthia',
#  'webmaster',
#  'metoo',
#  'revoluti',
#  'imperial',
#  'mick',
#  'audi',
#  'punk',
#  'summer99',
#  'jsbach',
#  '1021',
#  'pretzel',
#  'laura',
#  'transit',
#  'joseph1',
#  'muscles',
#  'muppet',
#  'mason1',
#  'bluesman',
#  'missy',
#  'lester',
#  'loose',
#  'madcat',
#  'shogun',
#  'adrian',
#  'reaper',
#  'illusion',
#  '1948',
#  'jester',
#  'donna1',
#  'daniel',
#  'cookie1',
#  'password',
#  '000001',
#  'candy',
#  'mellow',
#  'yellow1',
#  'handball',
#  'hammer1',
#  'stone1',
#  'boeing',
#  '565656',
#  'bond007',
#  'milton',
#  'egghead',
#  'callum',
#  'boston1',
#  'sounds',
#  'biscuit',
#  'sticks',
#  'whiteout',
#  'llll',
#  '1776',
#  'zone',
#  'native',
#  'jester',
#  'oxygen',
#  'jerk',
#  'gremlin',
#  'husker',
#  'tracy',
#  'peewee',
#  'jagger',
#  '2424',
#  'busty',
#  'candyman',
#  'road',
#  'doggies',
#  'judy',
#  'bonner',
#  'threesom',
#  'chuan',
#  'zelda',
#  'gibson',
#  'twister',
#  'dddddddd',
#  'john',
#  'racecar',
#  'xxxx',
#  'shock',
#  'colt45',
#  'pass1',
#  'daddy1',
#  'colt45',
#  'pisces',
#  'swimmer',
#  'matteo',
#  'buffet',
#  'sugar1',
#  'bbbb',
#  'cheng',
#  'womans',
#  'marcel',
#  'mountain',
#  'ironman',
#  'buffalo',
#  'butcher',
#  '426hemi',
#  'estelle',
#  'dundee',
#  'pictuers',
#  'coolhand',
#  'alexandr',
#  'outside',
#  'bigjim',
#  'pudding',
#  'lynn',
#  'spider',
#  'cwoui',
#  'store',
#  'hammer1',
#  '151515',
#  'valdez',
#  '1227',
#  'celica',
#  'paladin',
#  'route66',
#  'carla',
#  'teddy1',
#  'wheeler',
#  'remingto',
#  'candle',
#  'zorro1',
#  'cbr600',
#  'bolton',
#  '787878',
#  'woodland',
#  'cathy',
#  'tiger1',
#  'jayden',
#  'digital',
#  'bravo',
#  '222222',
#  'britney',
#  'mancity',
#  'pimpin',
#  'jean',
#  'castle',
#  'positive',
#  'junk',
#  'aspire',
#  'fishon',
#  'wookie',
#  'happyday',
#  'chiefs',
#  'titten',
#  'steeler',
#  'phantom',
#  'reptile',
#  'titan',
#  'mariners',
#  'burns',
#  'thewho',
#  'newpass6',
#  'flyfish',
#  'ticklish',
#  'acid',
#  'prince1',
#  'ticklish',
#  'joey',
#  'iscool',
#  'meat',
#  'meow',
#  'houston1',
#  'highbury',
#  'moses',
#  'walrus',
#  'anfield',
#  'vinnie',
#  'holmes',
#  'burning',
#  '1995',
#  'flyfish',
#  'bubba',
#  'reebok',
#  'hohoho',
#  'markie',
#  'barefoot',
#  'xander',
#  'akira',
#  'hawaii50',
#  'ripley',
#  '202020',
#  'knight',
#  'futbol',
#  'amanda',
#  'italy',
#  'insane',
#  'whisper',
#  'pauline',
#  'hothot',
#  'buffy',
#  'flying',
#  'katrina',
#  'monopoly',
#  'zaq123',
#  'candle',
#  'smiley',
#  'oliver1',
#  'seng',
#  'camper',
#  'shinobi',
#  'everett',
#  'laddie',
#  'doghouse',
#  'marcia',
#  'leeann',
#  'arthur',
#  'bossman',
#  'zhua',
#  'pimping',
#  'topher',
#  'insane',
#  'titten',
#  'route66',
#  'hobbit',
#  'picard',
#  'charlie',
#  'dolores',
#  'shalom',
#  'trader',
#  'martinez',
#  'dalton',
#  'keyboard',
#  'something',
#  'jason',
#  'picks',
#  'leopard',
#  'socrates',
#  'monalisa',
#  'tiger1',
#  'mexico',
#  'brady',
#  '123asd',
#  'frisky',
#  'tabitha',
#  'taco',
#  'doitnow',
#  'steven1',
#  '1985',
#  'steffi',
#  'moreno',
#  'nate',
#  'houdini',
#  'gryphon',
#  'song',
#  'stuart',
#  'cruise',
#  'jessica',
#  'baritone',
#  'abgrtyu',
#  'oldman',
#  'colorado',
#  'melons',
#  'erik',
#  'silent',
#  'wild',
#  'april1',
#  'tang',
#  'banane',
#  '000001',
#  'root',
#  'boozer',
#  'fiesta',
#  'awesome',
#  'hellos',
#  'some',
#  'cyclones',
#  'stefano',
#  'gandalf',
#  'chrysler',
#  'macdaddy',
#  'advance',
#  'shasta',
#  'devin',
#  'alejandr',
#  'wilbur',
#  'karina',
#  'pitures',
#  'redd',
#  'ryan',
#  '21212121',
#  'nothing',
#  'lllll',
#  'peanut',
#  'harold',
#  'serena',
#  'nintendo',
#  'onetwo',
#  '1977',
#  'passwd',
#  'house1',
#  'birdie',
#  'river',
#  'jewel',
#  'fountain',
#  'animated',
#  'lancelot',
#  'shodan',
#  'frodo',
#  'qwerty1',
#  'kevin',
#  'tracey',
#  'farscape',
#  'bigpoppa',
#  'barber',
#  'paint',
#  'drive',
#  'williams',
#  'camera',
#  'mollydog',
#  'terminat',
#  'stone',
#  '4ever',
#  'xuan',
#  'louis',
#  'popo',
#  'reckless',
#  'bohica',
#  '191919',
#  'mathew',
#  'spud',
#  'sweden',
#  'reggae',
#  'edwards',
#  'jeffrey',
#  'tekken',
#  'makaveli',
#  'modles',
#  'lantern',
#  'tintin',
#  'manman',
#  'boiler',
#  'alexia',
#  'jarhead',
#  'deerhunt',
#  'sleepy',
#  'word',
#  'valerie',
#  'pepe',
#  'bounty',
#  'dixie',
#  'wizard',
#  'access1',
#  'paramedi',
#  'nate',
#  'jaguar1',
#  'tickler',
#  'calico',
#  'again',
#  'biggie',
#  'trust',
#  'birdie',
#  'unicorn',
#  'anything',
#  'minemine',
#  'kiss',
#  'gamma',
#  'blondie',
#  'larkin',
#  'chichi',
#  'jeeper',
#  'chelsea1',
#  'thuglife',
#  'giggles',
#  'bigjohn',
#  'cedric',
#  'reds',
#  'santa',
#  'anders',
#  'utopia',
#  'sasha',
#  'easton',
#  'speaker',
#  'budman',
#  'drums',
#  'chucky',
#  'felipe',
#  'chat',
#  'rachel',
#  'newness',
#  'sheba1',
#  'travis1',
#  'gundam',
#  '4711',
#  'marijuan',
#  'rugby',
#  'cleaner',
#  'payday',
#  'brittany',
#  'briana',
#  'panasoni',
#  'ginger1',
#  'ringo',
#  'fist',
#  '99999999',
#  'manuel',
#  'fringe',
#  'hope',
#  'kipper',
#  'crazy1',
#  'faster',
#  'doggy1',
#  '21122112',
#  'eating',
#  'rampage',
#  'butch',
#  'nightwin',
#  'rimmer',
#  'wp2003wp',
#  'peter',
#  'wood',
#  'witch',
#  'sloppy',
#  'passwort',
#  'summer',
#  'birgit',
#  'window',
#  'eternity',
#  'samm',
#  'rusty1',
#  'rrrrrrrr',
#  'trout',
#  '1231',
#  'bbbbbbb',
#  'justin',
#  'loulou',
#  'modena',
#  '1021',
#  'mahler',
#  '57chevy',
#  'irishman',
#  'fullmoon',
#  'andy',
#  'grateful',
#  '12345678',
#  '1961',
#  'henry',
#  'dogman',
#  'mmmmmm',
#  'easton',
#  'access14',
#  'cable',
#  'pelican',
#  'malibu',
#  'bumper',
#  'doctor',
#  'aaron1',
#  'deadman',
#  'serena',
#  'merlin',
#  'fergie',
#  'patricia',
#  'space',
#  'highway',
#  'marcus',
#  'marilyn',
#  'dragon',
#  'chris1',
#  'westside',
#  'temple',
#  'chains',
#  'goth',
#  'albatros',
#  'really',
#  'terror',
#  'mario',
#  'babylon5',
#  'sweden',
#  'blue11',
#  'dave',
#  'cheeks',
#  'cars',
#  'sunset',
#  'hong',
#  'golfpro',
#  'dang',
#  'muffin1',
#  'moneys',
#  'frozen',
#  'asdf',
#  'nicole',
#  'tacoma',
#  'latino',
#  'adidas',
#  'design',
#  'airforce',
#  'kenny',
#  'idunno',
#  'cobain',
#  'freddie',
#  'tzpvaw',
#  'bambi',
#  'cosmo',
#  'vulcan',
#  'luna',
#  'finger',
#  'tulips',
#  'fishon',
#  'sunfire',
#  '1975',
#  'shovel',
#  'impreza',
#  'fischer',
#  'angelica',
#  'eric',
#  'susan',
#  'connor',
#  '369369',
#  'dwayne',
#  'jess',
#  'monsters',
#  'killkill',
#  'colombia',
#  'qwert123',
#  'maggie',
#  'jonny',
#  'kristy',
#  'lowrider',
#  'musicman',
#  'gabber',
#  '007007',
#  'martina',
#  'dallas1',
#  'walrus',
#  '1000',
#  'eeee',
#  'toast',
#  'bigman',
#  'scxakv',
#  'annabell',
#  'jeremiah',
#  'luke',
#  'trooper',
#  'sonoma',
#  'care1839',
#  'salasana',
#  'pudding',
#  'debra',
#  'frogman',
#  'meridian',
#  'powder',
#  'baba',
#  'marine',
#  'lickit',
#  'shaved',
#  '4242',
#  'morpheus',
#  'barton',
#  'diehard',
#  'neil',
#  'blue12',
#  'torres',
#  'goochi',
#  '20202020',
#  'ncc1701',
#  'another',
#  'lumber',
#  '123456',
#  'gabriell',
#  'slapshot',
#  'banker',
#  'jimmy1',
#  'gizmo',
#  'baritone',
#  'dnsadm',
#  'angelina',
#  'jarvis',
#  'duckman',
#  'seminole',
#  'sand',
#  'sheepdog',
#  'trinitro',
#  'zzzzzz',
#  'sinatra',
#  'doggie',
#  'tonight',
#  'bigones',
#  'nuggets',
#  'sahara',
#  'joanna',
#  'pass1234',
#  'butkus',
#  'mygirl',
#  'life',
#  'tequila',
#  'kissme',
#  'natalie1',
#  'canon',
#  'jaybird',
#  'ginscoot',
#  'cyborg',
#  'girsl',
#  '12345',
#  'killian',
#  'dentist',
#  'weiner',
#  '1017',
#  'bing',
#  'motley',
#  '77777',
#  'scandinavian',
#  'doghouse',
#  'bigdog',
#  'spikes',
#  'lian',
#  'amazing',
#  'piper',
#  'enterme',
#  'seth',
#  'delmar',
#  'runaway',
#  'dixie1',
#  'musashi',
#  'wallace',
#  'william1',
#  'madden',
#  'ground',
#  'tommy',
#  'keksa12',
#  'truelove',
#  'cubbies',
#  'garner',
#  'justine',
#  'mackie',
#  'bowser',
#  'sahara',
#  'manman',
#  'rambo',
#  'mariposa',
#  'sampson',
#  'temple',
#  'aaron',
#  'tyson',
#  'godfathe',
#  'tyson',
#  'farmer',
#  'bradford',
#  'slacker',
#  'babylon5',
#  'ursula',
#  'blink182',
#  'titten',
#  'skinny',
#  'camille',
#  'swimmer',
#  'team',
#  'operator',
#  'helper',
#  'zippo',
#  'fullback',
#  'sassy',
#  'renault',
#  'punisher',
#  'microsoft',
#  'ning',
#  'bowling',
#  'hjkl',
#  '11223344',
#  'glennwei',
#  'ultimate',
#  '1007',
#  'beanie',
#  'novell',
#  'conover',
#  'steve',
#  'rimmer',
#  'tuna',
#  '1007',
#  'orange',
#  'homeboy',
#  'supernov',
#  'chuckles',
#  'smiley',
#  'candace',
#  'steven1',
#  'battle',
#  'place',
#  'honda1',
#  '1221',
#  'married',
#  'smile1',
#  'peaches',
#  'wizard',
#  'loveya',
#  'punkrock',
#  'holly1',
#  'robert',
#  'tatiana',
#  'sommer',
#  'thor',
#  'sugar1',
#  'nick',
#  'pookie',
#  'teddy',
#  'babygirl',
#  'seminole',
#  'band',
#  'riversid',
#  'gambler',
#  'shaman',
#  'fishy',
#  'explore',
#  'engineer',
#  '123456',
#  'lllll',
#  'vides',
#  'nemrac58',
#  'virginie',
#  'ernie',
#  'baritone',
#  'mulder',
#  '1a2b3c',
#  'dimples',
#  'tinker',
#  'bumble',
#  'renault',
#  'martini',
#  'cabbage',
#  'simple1',
#  'lumber',
#  'hornets',
#  'penguin1',
#  'scarlet',
#  'scott',
#  'martin1',
#  'springs',
#  'race',
#  'loveit',
#  'wind',
#  'belly',
#  'fdsa',
#  'redline',
#  'toon',
#  'snowboar',
#  'baller',
#  'dian',
#  'toolman',
#  'funfun',
#  '2112',
#  'iomega',
#  'jenjen',
#  'adam12',
#  'wetter',
#  'hallie',
#  'frodo1',
#  'oakland',
#  'candace',
#  'racers',
#  'vh5150',
#  'maxime',
#  'cookies',
#  'shanti',
#  'mikemike',
#  'twinkle',
#  '4417',
#  'blake',
#  'skinny',
#  'secure',
#  'hallowee',
#  'sasha1',
#  'willis',
#  'choke',
#  'lisalisa',
#  'project',
#  'cooper',
#  'reality',
#  'sugar',
#  'friend',
#  'impact',
#  'bill',
#  'enigma',
#  '323232',
#  'benny',
#  'pipeline',
#  '1225',
#  'dundee',
#  'chambers',
#  'treble',
#  '313131',
#  'geronimo',
#  'einstein',
#  'lips',
#  'maverick',
#  'mackie',
#  'river',
#  'bangkok',
#  'metal',
#  'zhen',
#  'beau',
#  'rated',
#  'lobo',
#  'sammy',
#  'films',
#  'ming',
#  'rocky1',
#  'hugo',
#  'beach',
#  'tara',
#  'orlando',
#  'vivid',
#  'sakura',
#  'justine',
#  'freaky',
#  'elvis',
#  'tiberius',
#  'outkast',
#  'butterfl',
#  'eggplant',
#  'veronika',
#  'snappy',
#  'michaela',
#  'zuan',
#  'tintin',
#  'store',
#  'seamus',
#  'cable',
#  'ginger',
#  'eddie1',
#  'niang',
#  'zzzzzzzz',
#  'bikini',
#  'squall',
#  'insanity',
#  'davidson',
#  'kikimora',
#  'snowball',
#  'zhua',
#  'climber',
#  'teddy',
#  'gene',
#  'carlo',
#  'poiu',
#  'casper1',
#  'mini',
#  'kelvin',
#  'lenny',
#  'money',
#  'india',
#  'sssssss',
#  'applepie',
#  'philips',
#  'faster',
#  '565656',
#  'hamish',
#  'martin1',
#  'louie',
#  'fringe',
#  'camaro',
#  'farley',
#  'golf',
#  'joanna',
#  'tuna',
#  'oklahoma',
#  'blacklab',
#  '12121212',
#  'omega1',
#  'zxcv',
#  'chandler',
#  'patriots',
#  'leopard',
#  'hello1',
#  'probes',
#  'samsam',
#  'harry1',
#  'gorgeous',
#  'stripper',
#  'mankind',
#  'patriots',
#  'leslie',
#  'bluejay',
#  'hello',
#  'pepito',
#  'mechanic',
#  'palmer',
#  'beavis1',
#  'stealth',
#  'fishin',
#  'hawkeye',
#  '686868',
#  'arthur',
#  'penetrating',
#  'kenwood',
#  'scrapper',
#  'bubba',
#  'wildone',
#  'swinger',
#  'bolton',
#  'almond',
#  'scarface',
#  'sheeba',
#  'landon',
#  'martini',
#  'poker',
#  'kahuna',
#  'cosmo',
#  'austin1',
#  'pooh',
#  'colt',
#  'dingle',
#  'transit',
#  'easter',
#  'tulips',
#  'citroen',
#  'damon',
#  'dookie',
#  'jackjack',
#  'chocolate',
#  'rain',
#  ...]

# %%
password
# Out:
# ['jethro',
#  'tanner',
#  'downtown',
#  'doudou',
#  'lockerroom',
#  'shalom',
#  'jonas',
#  'great',
#  'cold',
#  'darkness',
#  'wizard',
#  'romero',
#  'cottage',
#  '1965',
#  'cobain',
#  'memphis',
#  'loveme',
#  'sinbad',
#  'yousuck',
#  'pokey',
#  '1022',
#  'dean',
#  'stevens',
#  'coochie',
#  'roscoe',
#  'beast',
#  'apples',
#  'maxime',
#  'danny1',
#  'yong',
#  'steele',
#  'calgary',
#  'rusty1',
#  'spurs',
#  'coming',
#  'clowns',
#  'facial',
#  'qwertz',
#  'corn',
#  'service',
#  'dakota',
#  'skyler',
#  'fruity',
#  'willis',
#  'theresa',
#  'shakur',
#  'emmett',
#  'backup',
#  'sabine',
#  'manfred',
#  'tickling',
#  'blunt',
#  'silver',
#  'wild',
#  'yamahar1',
#  'tito',
#  'drifter',
#  'mexico',
#  'island',
#  'cloud',
#  'evolutio',
#  'life',
#  '1234567',
#  'katie',
#  'kahlua',
#  'trucking',
#  'isabel',
#  'peter',
#  'hannah',
#  'twilight',
#  'tracker',
#  'irish',
#  'sweety',
#  'doubled',
#  'chicken1',
#  'time',
#  'transit',
#  'beavis1',
#  'carnage',
#  '112358',
#  'dude',
#  'buffalo',
#  'challeng',
#  'europa',
#  'aptiva',
#  'pauline',
#  'phoebe',
#  'comet',
#  'catwoman',
#  'mother',
#  'corwin',
#  'cynthia',
#  'webmaster',
#  'metoo',
#  'revoluti',
#  'imperial',
#  'mick',
#  'audi',
#  'punk',
#  'summer99',
#  'jsbach',
#  '1021',
#  'pretzel',
#  'laura',
#  'transit',
#  'joseph1',
#  'muscles',
#  'muppet',
#  'mason1',
#  'bluesman',
#  'missy',
#  'lester',
#  'loose',
#  'madcat',
#  'shogun',
#  'adrian',
#  'reaper',
#  'illusion',
#  '1948',
#  'jester',
#  'donna1',
#  'daniel',
#  'cookie1',
#  'password',
#  '000001',
#  'candy',
#  'mellow',
#  'yellow1',
#  'handball',
#  'hammer1',
#  'stone1',
#  'boeing',
#  '565656',
#  'bond007',
#  'milton',
#  'egghead',
#  'callum',
#  'boston1',
#  'sounds',
#  'biscuit',
#  'sticks',
#  'whiteout',
#  'llll',
#  '1776',
#  'zone',
#  'native',
#  'jester',
#  'oxygen',
#  'jerk',
#  'gremlin',
#  'husker',
#  'tracy',
#  'peewee',
#  'jagger',
#  '2424',
#  'busty',
#  'candyman',
#  'road',
#  'doggies',
#  'judy',
#  'bonner',
#  'threesom',
#  'chuan',
#  'zelda',
#  'gibson',
#  'twister',
#  'dddddddd',
#  'john',
#  'racecar',
#  'xxxx',
#  'shock',
#  'colt45',
#  'pass1',
#  'daddy1',
#  'colt45',
#  'pisces',
#  'swimmer',
#  'matteo',
#  'buffet',
#  'sugar1',
#  'bbbb',
#  'cheng',
#  'womans',
#  'marcel',
#  'mountain',
#  'ironman',
#  'buffalo',
#  'butcher',
#  '426hemi',
#  'estelle',
#  'dundee',
#  'pictuers',
#  'coolhand',
#  'alexandr',
#  'outside',
#  'bigjim',
#  'pudding',
#  'lynn',
#  'spider',
#  'cwoui',
#  'store',
#  'hammer1',
#  '151515',
#  'valdez',
#  '1227',
#  'celica',
#  'paladin',
#  'route66',
#  'carla',
#  'teddy1',
#  'wheeler',
#  'remingto',
#  'candle',
#  'zorro1',
#  'cbr600',
#  'bolton',
#  '787878',
#  'woodland',
#  'cathy',
#  'tiger1',
#  'jayden',
#  'digital',
#  'bravo',
#  '222222',
#  'britney',
#  'mancity',
#  'pimpin',
#  'jean',
#  'castle',
#  'positive',
#  'junk',
#  'aspire',
#  'fishon',
#  'wookie',
#  'happyday',
#  'chiefs',
#  'titten',
#  'steeler',
#  'phantom',
#  'reptile',
#  'titan',
#  'mariners',
#  'burns',
#  'thewho',
#  'newpass6',
#  'flyfish',
#  'ticklish',
#  'acid',
#  'prince1',
#  'ticklish',
#  'joey',
#  'iscool',
#  'meat',
#  'meow',
#  'houston1',
#  'highbury',
#  'moses',
#  'walrus',
#  'anfield',
#  'vinnie',
#  'holmes',
#  'burning',
#  '1995',
#  'flyfish',
#  'bubba',
#  'reebok',
#  'hohoho',
#  'markie',
#  'barefoot',
#  'xander',
#  'akira',
#  'hawaii50',
#  'ripley',
#  '202020',
#  'knight',
#  'futbol',
#  'amanda',
#  'italy',
#  'insane',
#  'whisper',
#  'pauline',
#  'hothot',
#  'buffy',
#  'flying',
#  'katrina',
#  'monopoly',
#  'zaq123',
#  'candle',
#  'smiley',
#  'oliver1',
#  'seng',
#  'camper',
#  'shinobi',
#  'everett',
#  'laddie',
#  'doghouse',
#  'marcia',
#  'leeann',
#  'arthur',
#  'bossman',
#  'zhua',
#  'pimping',
#  'topher',
#  'insane',
#  'titten',
#  'route66',
#  'hobbit',
#  'picard',
#  'charlie',
#  'dolores',
#  'shalom',
#  'trader',
#  'martinez',
#  'dalton',
#  'keyboard',
#  'something',
#  'jason',
#  'picks',
#  'leopard',
#  'socrates',
#  'monalisa',
#  'tiger1',
#  'mexico',
#  'brady',
#  '123asd',
#  'frisky',
#  'tabitha',
#  'taco',
#  'doitnow',
#  'steven1',
#  '1985',
#  'steffi',
#  'moreno',
#  'nate',
#  'houdini',
#  'gryphon',
#  'song',
#  'stuart',
#  'cruise',
#  'jessica',
#  'baritone',
#  'abgrtyu',
#  'oldman',
#  'colorado',
#  'melons',
#  'erik',
#  'silent',
#  'wild',
#  'april1',
#  'tang',
#  'banane',
#  '000001',
#  'root',
#  'boozer',
#  'fiesta',
#  'awesome',
#  'hellos',
#  'some',
#  'cyclones',
#  'stefano',
#  'gandalf',
#  'chrysler',
#  'macdaddy',
#  'advance',
#  'shasta',
#  'devin',
#  'alejandr',
#  'wilbur',
#  'karina',
#  'pitures',
#  'redd',
#  'ryan',
#  '21212121',
#  'nothing',
#  'lllll',
#  'peanut',
#  'harold',
#  'serena',
#  'nintendo',
#  'onetwo',
#  '1977',
#  'passwd',
#  'house1',
#  'birdie',
#  'river',
#  'jewel',
#  'fountain',
#  'animated',
#  'lancelot',
#  'shodan',
#  'frodo',
#  'qwerty1',
#  'kevin',
#  'tracey',
#  'farscape',
#  'bigpoppa',
#  'barber',
#  'paint',
#  'drive',
#  'williams',
#  'camera',
#  'mollydog',
#  'terminat',
#  'stone',
#  '4ever',
#  'xuan',
#  'louis',
#  'popo',
#  'reckless',
#  'bohica',
#  '191919',
#  'mathew',
#  'spud',
#  'sweden',
#  'reggae',
#  'edwards',
#  'jeffrey',
#  'tekken',
#  'makaveli',
#  'modles',
#  'lantern',
#  'tintin',
#  'manman',
#  'boiler',
#  'alexia',
#  'jarhead',
#  'deerhunt',
#  'sleepy',
#  'word',
#  'valerie',
#  'pepe',
#  'bounty',
#  'dixie',
#  'wizard',
#  'access1',
#  'paramedi',
#  'nate',
#  'jaguar1',
#  'tickler',
#  'calico',
#  'again',
#  'biggie',
#  'trust',
#  'birdie',
#  'unicorn',
#  'anything',
#  'minemine',
#  'kiss',
#  'gamma',
#  'blondie',
#  'larkin',
#  'chichi',
#  'jeeper',
#  'chelsea1',
#  'thuglife',
#  'giggles',
#  'bigjohn',
#  'cedric',
#  'reds',
#  'santa',
#  'anders',
#  'utopia',
#  'sasha',
#  'easton',
#  'speaker',
#  'budman',
#  'drums',
#  'chucky',
#  'felipe',
#  'chat',
#  'rachel',
#  'newness',
#  'sheba1',
#  'travis1',
#  'gundam',
#  '4711',
#  'marijuan',
#  'rugby',
#  'cleaner',
#  'payday',
#  'brittany',
#  'briana',
#  'panasoni',
#  'ginger1',
#  'ringo',
#  'fist',
#  '99999999',
#  'manuel',
#  'fringe',
#  'hope',
#  'kipper',
#  'crazy1',
#  'faster',
#  'doggy1',
#  '21122112',
#  'eating',
#  'rampage',
#  'butch',
#  'nightwin',
#  'rimmer',
#  'wp2003wp',
#  'peter',
#  'wood',
#  'witch',
#  'sloppy',
#  'passwort',
#  'summer',
#  'birgit',
#  'window',
#  'eternity',
#  'samm',
#  'rusty1',
#  'rrrrrrrr',
#  'trout',
#  '1231',
#  'bbbbbbb',
#  'justin',
#  'loulou',
#  'modena',
#  '1021',
#  'mahler',
#  '57chevy',
#  'irishman',
#  'fullmoon',
#  'andy',
#  'grateful',
#  '12345678',
#  '1961',
#  'henry',
#  'dogman',
#  'mmmmmm',
#  'easton',
#  'access14',
#  'cable',
#  'pelican',
#  'malibu',
#  'bumper',
#  'doctor',
#  'aaron1',
#  'deadman',
#  'serena',
#  'merlin',
#  'fergie',
#  'patricia',
#  'space',
#  'highway',
#  'marcus',
#  'marilyn',
#  'dragon',
#  'chris1',
#  'westside',
#  'temple',
#  'chains',
#  'goth',
#  'albatros',
#  'really',
#  'terror',
#  'mario',
#  'babylon5',
#  'sweden',
#  'blue11',
#  'dave',
#  'cheeks',
#  'cars',
#  'sunset',
#  'hong',
#  'golfpro',
#  'dang',
#  'muffin1',
#  'moneys',
#  'frozen',
#  'asdf',
#  'nicole',
#  'tacoma',
#  'latino',
#  'adidas',
#  'design',
#  'airforce',
#  'kenny',
#  'idunno',
#  'cobain',
#  'freddie',
#  'tzpvaw',
#  'bambi',
#  'cosmo',
#  'vulcan',
#  'luna',
#  'finger',
#  'tulips',
#  'fishon',
#  'sunfire',
#  '1975',
#  'shovel',
#  'impreza',
#  'fischer',
#  'angelica',
#  'eric',
#  'susan',
#  'connor',
#  '369369',
#  'dwayne',
#  'jess',
#  'monsters',
#  'killkill',
#  'colombia',
#  'qwert123',
#  'maggie',
#  'jonny',
#  'kristy',
#  'lowrider',
#  'musicman',
#  'gabber',
#  '007007',
#  'martina',
#  'dallas1',
#  'walrus',
#  '1000',
#  'eeee',
#  'toast',
#  'bigman',
#  'scxakv',
#  'annabell',
#  'jeremiah',
#  'luke',
#  'trooper',
#  'sonoma',
#  'care1839',
#  'salasana',
#  'pudding',
#  'debra',
#  'frogman',
#  'meridian',
#  'powder',
#  'baba',
#  'marine',
#  'lickit',
#  'shaved',
#  '4242',
#  'morpheus',
#  'barton',
#  'diehard',
#  'neil',
#  'blue12',
#  'torres',
#  'goochi',
#  '20202020',
#  'ncc1701',
#  'another',
#  'lumber',
#  '123456',
#  'gabriell',
#  'slapshot',
#  'banker',
#  'jimmy1',
#  'gizmo',
#  'baritone',
#  'dnsadm',
#  'angelina',
#  'jarvis',
#  'duckman',
#  'seminole',
#  'sand',
#  'sheepdog',
#  'trinitro',
#  'zzzzzz',
#  'sinatra',
#  'doggie',
#  'tonight',
#  'bigones',
#  'nuggets',
#  'sahara',
#  'joanna',
#  'pass1234',
#  'butkus',
#  'mygirl',
#  'life',
#  'tequila',
#  'kissme',
#  'natalie1',
#  'canon',
#  'jaybird',
#  'ginscoot',
#  'cyborg',
#  'girsl',
#  '12345',
#  'killian',
#  'dentist',
#  'weiner',
#  '1017',
#  'bing',
#  'motley',
#  '77777',
#  'scandinavian',
#  'doghouse',
#  'bigdog',
#  'spikes',
#  'lian',
#  'amazing',
#  'piper',
#  'enterme',
#  'seth',
#  'delmar',
#  'runaway',
#  'dixie1',
#  'musashi',
#  'wallace',
#  'william1',
#  'madden',
#  'ground',
#  'tommy',
#  'keksa12',
#  'truelove',
#  'cubbies',
#  'garner',
#  'justine',
#  'mackie',
#  'bowser',
#  'sahara',
#  'manman',
#  'rambo',
#  'mariposa',
#  'sampson',
#  'temple',
#  'aaron',
#  'tyson',
#  'godfathe',
#  'tyson',
#  'farmer',
#  'bradford',
#  'slacker',
#  'babylon5',
#  'ursula',
#  'blink182',
#  'titten',
#  'skinny',
#  'camille',
#  'swimmer',
#  'team',
#  'operator',
#  'helper',
#  'zippo',
#  'fullback',
#  'sassy',
#  'renault',
#  'punisher',
#  'microsoft',
#  'ning',
#  'bowling',
#  'hjkl',
#  '11223344',
#  'glennwei',
#  'ultimate',
#  '1007',
#  'beanie',
#  'novell',
#  'conover',
#  'steve',
#  'rimmer',
#  'tuna',
#  '1007',
#  'orange',
#  'homeboy',
#  'supernov',
#  'chuckles',
#  'smiley',
#  'candace',
#  'steven1',
#  'battle',
#  'place',
#  'honda1',
#  '1221',
#  'married',
#  'smile1',
#  'peaches',
#  'wizard',
#  'loveya',
#  'punkrock',
#  'holly1',
#  'robert',
#  'tatiana',
#  'sommer',
#  'thor',
#  'sugar1',
#  'nick',
#  'pookie',
#  'teddy',
#  'babygirl',
#  'seminole',
#  'band',
#  'riversid',
#  'gambler',
#  'shaman',
#  'fishy',
#  'explore',
#  'engineer',
#  '123456',
#  'lllll',
#  'vides',
#  'nemrac58',
#  'virginie',
#  'ernie',
#  'baritone',
#  'mulder',
#  '1a2b3c',
#  'dimples',
#  'tinker',
#  'bumble',
#  'renault',
#  'martini',
#  'cabbage',
#  'simple1',
#  'lumber',
#  'hornets',
#  'penguin1',
#  'scarlet',
#  'scott',
#  'martin1',
#  'springs',
#  'race',
#  'loveit',
#  'wind',
#  'belly',
#  'fdsa',
#  'redline',
#  'toon',
#  'snowboar',
#  'baller',
#  'dian',
#  'toolman',
#  'funfun',
#  '2112',
#  'iomega',
#  'jenjen',
#  'adam12',
#  'wetter',
#  'hallie',
#  'frodo1',
#  'oakland',
#  'candace',
#  'racers',
#  'vh5150',
#  'maxime',
#  'cookies',
#  'shanti',
#  'mikemike',
#  'twinkle',
#  '4417',
#  'blake',
#  'skinny',
#  'secure',
#  'hallowee',
#  'sasha1',
#  'willis',
#  'choke',
#  'lisalisa',
#  'project',
#  'cooper',
#  'reality',
#  'sugar',
#  'friend',
#  'impact',
#  'bill',
#  'enigma',
#  '323232',
#  'benny',
#  'pipeline',
#  '1225',
#  'dundee',
#  'chambers',
#  'treble',
#  '313131',
#  'geronimo',
#  'einstein',
#  'lips',
#  'maverick',
#  'mackie',
#  'river',
#  'bangkok',
#  'metal',
#  'zhen',
#  'beau',
#  'rated',
#  'lobo',
#  'sammy',
#  'films',
#  'ming',
#  'rocky1',
#  'hugo',
#  'beach',
#  'tara',
#  'orlando',
#  'vivid',
#  'sakura',
#  'justine',
#  'freaky',
#  'elvis',
#  'tiberius',
#  'outkast',
#  'butterfl',
#  'eggplant',
#  'veronika',
#  'snappy',
#  'michaela',
#  'zuan',
#  'tintin',
#  'store',
#  'seamus',
#  'cable',
#  'ginger',
#  'eddie1',
#  'niang',
#  'zzzzzzzz',
#  'bikini',
#  'squall',
#  'insanity',
#  'davidson',
#  'kikimora',
#  'snowball',
#  'zhua',
#  'climber',
#  'teddy',
#  'gene',
#  'carlo',
#  'poiu',
#  'casper1',
#  'mini',
#  'kelvin',
#  'lenny',
#  'money',
#  'india',
#  'sssssss',
#  'applepie',
#  'philips',
#  'faster',
#  '565656',
#  'hamish',
#  'martin1',
#  'louie',
#  'fringe',
#  'camaro',
#  'farley',
#  'golf',
#  'joanna',
#  'tuna',
#  'oklahoma',
#  'blacklab',
#  '12121212',
#  'omega1',
#  'zxcv',
#  'chandler',
#  'patriots',
#  'leopard',
#  'hello1',
#  'probes',
#  'samsam',
#  'harry1',
#  'gorgeous',
#  'stripper',
#  'mankind',
#  'patriots',
#  'leslie',
#  'bluejay',
#  'hello',
#  'pepito',
#  'mechanic',
#  'palmer',
#  'beavis1',
#  'stealth',
#  'fishin',
#  'hawkeye',
#  '686868',
#  'arthur',
#  'penetrating',
#  'kenwood',
#  'scrapper',
#  'bubba',
#  'wildone',
#  'swinger',
#  'bolton',
#  'almond',
#  'scarface',
#  'sheeba',
#  'landon',
#  'martini',
#  'poker',
#  'kahuna',
#  'cosmo',
#  'austin1',
#  'pooh',
#  'colt',
#  'dingle',
#  'transit',
#  'easter',
#  'tulips',
#  'citroen',
#  'damon',
#  'dookie',
#  'jackjack',
#  'chocolate',
#  'rain',
#  ...]

# %%
customer = pd.read_csv("C:/ram/FALL/DMQL/Project/customer.csv")
Account_Details = pd.read_csv("C:/ram/FALL/DMQL/Project/Account_Details.csv")


customer['ID'].tolist()

#Account_Details['Account_no']
# Out:
# 0       6614212
# 1       6716543
# 2       8601028
# 3       7446086
# 4       4122549
#          ...
# 9995    8532903
# 9996    5078380
# 9997    8554324
# 9998    9673332
# 9999    5590098
# Name: ID, Length: 10000, dtype: int64

# %%
Login = pd.DataFrame (customer['ID'].tolist(), columns = ['User_Id'])
Login['password'] = password
Login['Account_no'] =Account_Details['Account_no']

Login
# Out:
#       User_Id    password        Account_no
# 0     6614212      jethro  1032665555259110
# 1     6716543      tanner  1022457127705150
# 2     8601028    downtown  1034377768495020
# 3     7446086      doudou  1030517720272910
# 4     4122549  lockerroom  1018800232477030
# ...       ...         ...               ...
# 9995  8532903      fergus  1020805612047480
# 9996  5078380    monalisa  1070610451281470
# 9997  8554324      armani  1061135450628380
# 9998  9673332    rosemary  1088222785375750
# 9999  5590098        load  1024251000827920
#
# [10000 rows x 3 columns]

# %%
Login.to_csv('Login.csv')
