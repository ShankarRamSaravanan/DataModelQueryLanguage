# %%
from datetime import datetime

import numpy as np

Time_stamp = np.random.randint(1609477200,1664596800,size=(20000), dtype=np.int64)

date_time=[]
for i in Time_stamp:
    date_time.append(str(datetime.fromtimestamp(i)))

date_time
# Out:
# ['2021-11-07 18:55:59',
#  '2021-06-10 14:50:40',
#  '2022-05-10 09:32:37',
#  '2021-12-28 12:31:27',
#  '2021-11-26 02:08:16',
#  '2022-06-14 05:10:29',
#  '2022-04-02 00:27:26',
#  '2021-07-22 22:57:35',
#  '2021-04-29 05:27:57',
#  '2021-08-22 21:01:39',
#  '2021-04-21 14:28:28',
#  '2022-06-03 10:35:55',
#  '2022-06-04 22:52:23',
#  '2022-06-29 09:51:21',
#  '2021-04-21 09:49:14',
#  '2021-07-12 02:04:32',
#  '2022-01-02 10:47:46',
#  '2021-05-22 21:11:33',
#  '2021-10-01 18:20:05',
#  '2021-01-13 16:26:59',
#  '2021-09-29 22:17:20',
#  '2022-01-30 06:42:12',
#  '2022-01-10 19:55:47',
#  '2021-08-26 09:01:22',
#  '2022-09-25 05:52:21',
#  '2021-03-22 09:58:50',
#  '2022-06-24 00:06:15',
#  '2021-05-21 17:05:13',
#  '2021-12-22 17:24:13',
#  '2021-06-27 22:02:53',
#  '2021-05-29 15:49:58',
#  '2022-07-28 21:10:04',
#  '2021-08-21 11:57:05',
#  '2021-06-25 00:56:04',
#  '2022-04-25 09:55:39',
#  '2022-07-29 17:04:48',
#  '2022-04-24 23:04:32',
#  '2022-01-26 07:15:23',
# ...

# %%
from urllib import request, error
from urllib.parse import urlencode
import json
import time
import re 
API_VERSION = '1.3'
import pandas as pd
import time



Transaction_Id=[]
for i in range(20000):
    URL = 'https://randomuser.me/api/?nat=us'.format(API_VERSION)   
    JSON_FILE = json.loads(request.urlopen(URL).read())
    Title =JSON_FILE['results'][0]['login']['md5']
    Transaction_Id.append(Title[0:15])

# %%
Transaction_Id
# Out:
# ['84be36dd9063ce9',
#  'd12ccdf44613fd4',
#  '0c5c6b77c89befb',
#  '218cfd047490d14',
#  'ddb6f9dc0ec9c63',
#  '41dd71480fe0e0c',
#  '190807babd47031',
#  '798ce4e3d938bf6',
#  '18c3b787d4baefc',
#  '184966da8e02b14',
#  '06f58d0b8b19561',
#  '7f4f1e9143e4f17',
#  '5644ad716af0874',
#  '454d41cc90ca77f',
#  '40722228e66583e',
#  '44da8142c6a272b',
#  '1900cc6d3d43924',
#  '6121637a4dd3ef6',
#  '8edf146e1171f15',
#  'd451c59c54543cc',
#  '9cc0c6b8f9fc26b',
#  'c80418eafaca5fe',
#  '8f2fbfc5b0a9a9d',
#  '207e7b7b9068f21',
#  'cd0134a9fe4e912',
#  'e2f15a863f0acdd',
#  '51b734a7060c7bb',
#  '2ff24779140d854',
#  '07cc68a75d8b91c',
#  '740868d8403d7ba',
#  '29f3ef72990df99',
#  '8dca029fcd804d6',
#  'f4b5e9c682fe6d5',
#  'f4b28ee2fd0d8c8',
#  '714d11a5cf14ae1',
#  '9bd56d6f05ff1df',
#  '20fc0ff06f690e0',
#  'cd9ac5aeea32872',
#  'd104da1e485bd2b',
#  '27fcaa58eb74067',
#  '8f6ae0aac9102ac',
#  'b7365a23c5f8711',
#  '9e28b797b0e9e16',
#  '219e6633f906a77',
#  '03335d8b0f84483',
# ...

# %%
Transaction_mode = ['NEFT', 'RTGS','Wire Transfer','Cheque','UPI']


a=np.random.randint(4, size=20000)




Transaction_mode_updated =[]
for i in a:
   Transaction_mode_updated.append(Transaction_mode[i])   
print(Transaction_mode_updated)
# Out:
# ['Cheque', 'Cheque', 'NEFT', 'RTGS', 'NEFT', 'Wire Transfer', 'RTGS', 'NEFT', 'Cheque', 'Wire Transfer', 'NEFT', 'NEFT', 'RTGS', 'NEFT', 'NEFT', 'Wire Transfer', 'RTGS', 'RTGS', 'NEFT', 'NEFT', 'Cheque', 'Cheque', 'Wire Transfer', 'Wire Transfer', 'RTGS', 'Cheque', 'NEFT', 'NEFT', 'Cheque', 'RTGS', 'Wire Transfer', 'Cheque', 'RTGS', 'Wire Transfer', 'RTGS', 'RTGS', 'RTGS', 'Cheque', 'NEFT', 'RTGS', 'RTGS', 'NEFT', 'Cheque', 'Wire Transfer', 'Wire Transfer', 'NEFT', 'Wire Transfer', 'Cheque', 'RTGS', 'Wire Transfer', 'RTGS', 'NEFT', 'NEFT', 'RTGS', 'Wire Transfer', 'Wire Transfer', 'NEFT', 'RTGS', 'Wire Transfer', 'RTGS', 'NEFT', 'Wire Transfer', 'NEFT', 'RTGS', 'RTGS', 'RTGS', 'Wire Transfer', 'Wire Transfer', 'NEFT', 'RTGS', 'Wire Transfer', 'NEFT', 'Wire Transfer', 'NEFT', 'RTGS', 'Wire Transfer', 'RTGS', 'NEFT', 'RTGS', 'Cheque', 'Cheque', 'Cheque', 'Wire Transfer', 'Wire Transfer', 'Wire Transfer', 'NEFT', 'RTGS', 'Wire Transfer', 'Wire Transfer', 'NEFT', 'RTGS', 'RTGS', 'RTGS', 
# ...

# %%
import random


b=np.random.randint(2, size=20000)
Transaction_mode = ["+","-"]

amount=[]
for i in b:
    Amount = random.randrange(100,60000,225)
    updated_amount = Transaction_mode[i] + str(Amount)
    amount.append(updated_amount)
    
    
amount
# Out:
# ['-37225',
#  '+14725',
#  '+38125',
#  '+27100',
#  '-30700',
#  '-17200',
#  '-41725',
#  '+39925',
#  '-19225',
#  '+18325',
#  '+33400',
#  '+23050',
#  '-44875',
#  '+51400',
#  '-30025',
#  '+53200',
#  '+9550',
#  '-27100',
#  '+56350',
#  '-39025',
#  '+1225',
#  '+51175',
#  '-27325',
#  '+5275',
#  '+23725',
#  '+47800',
#  '-43750',
#  '+12700',
#  '+57925',
#  '+2350',
#  '-11800',
#  '-15850',
#  '-46450',
#  '-19225',
#  '+15400',
#  '-32950',
#  '-42625',
#  '+16975',
#  '-56125',
#  '-53650',
#  '+30475',
#  '-50050',
#  '-10675',
#  '+59275',
#  '-46675',
#  '+12475',
#  '+20125',
#  '+325',
#  '+12250',
#  '-14725',
#  '-17200',
#  '-24625',
#  '+8875',
#  '-7300',
#  '-2125',
#  '+22825',
#  '+47125',
#  '-30475',
#  '-6850',
#  '-6850',
#  '+33850',
#  '+52075',
#  '-1225',
#  '+775',
#  '-56800',
#  '-13825',
#  '-49600',
#  '-29575',
#  '-41725',
#  '-52750',
#  '-45325',
#  '-41725',
#  '+50950',
#  '+55225',
#  '+34300',
#  '-58375',
#  '+42400',
#  '+8425',
# ...

# %%
import pandas as pd


login = pd.read_csv("C:/ram/FALL/DMQL/Project/Login.csv")


account_no=login['Account_no'].tolist()


account_no
# Out:
# [1079450000000000.0,
#  1057150000000000.0,
#  1012830000000000.0,
#  1037600000000000.0,
#  1040140000000000.0,
#  1052030000000000.0,
#  1078630000000000.0,
#  1047190000000000.0,
#  1042280000000000.0,
#  1095330000000000.0,
#  1063940000000000.0,
#  1063480000000000.0,
#  1084610000000000.0,
#  1085710000000000.0,
#  1092940000000000.0,
#  1014770000000000.0,
#  1077470000000000.0,
#  1080950000000000.0,
#  1044040000000000.0,
#  1083470000000000.0,
#  1091040000000000.0,
#  1075040000000000.0,
#  1081810000000000.0,
#  1038960000000000.0,
#  1012490000000000.0,
#  1067290000000000.0,
#  1016890000000000.0,
#  1032760000000000.0,
#  1045300000000000.0,
#  1030390000000000.0,
#  1044210000000000.0,
#  1048120000000000.0,
#  1092440000000000.0,
#  1087090000000000.0,
#  1096250000000000.0,
#  1036560000000000.0,
#  1076030000000000.0,
#  1073150000000000.0,
#  1045520000000000.0,
#  1060000000000000.0,
#  1061260000000000.0,
#  1028670000000000.0,
#  1054280000000000.0,
# ...

# %%
Transaction = pd.DataFrame(Transaction_Id, columns=['Transacton_Id'])
Transaction['Account_no']=account_no



Transaction
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [45], in <cell line: 2>()
#       1 Transaction = pd.DataFrame(Transaction_Id, columns=['Transacton_Id'])
# ----> 2 Transaction['Account_no']=account_no
#       6 Transaction
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3655, in DataFrame.__setitem__(self, key, value)
#    3652     self._setitem_array([key], value)
#    3653 else:
#    3654     # set column
# -> 3655     self._set_item(key, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3832, in DataFrame._set_item(self, key, value)
#    3822 def _set_item(self, key, value) -> None:
#    3823     """
#    3824     Add series to DataFrame in specified column.
#    3825
#    (...)
#    3830     ensure homogeneity.
#    3831     """
# -> 3832     value = self._sanitize_column(value)
#    3834     if (
#    3835         key in self.columns
# ...
